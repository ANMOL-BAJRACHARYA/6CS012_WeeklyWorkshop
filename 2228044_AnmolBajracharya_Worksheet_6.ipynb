# %% [markdown]
# ## **Simple CNN Implemented using Keras.**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tensorflow import keras
from tensorflow.keras import layers
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Task 1: Data Understanding and Visualization:**

# %%
train_dir = "/content/drive/MyDrive/AI_ML/FruitinAmazon/FruitinAmazon/train"  # Change this to your actual dataset path
test_dir = "/content/drive/MyDrive/AI_ML/FruitinAmazon/FruitinAmazon/test"
classes = os.listdir(train_dir)  # Get list of class directories

# %% [markdown]
# 1. Load and visualize images from a dataset stored in directories, where each subdirec-
# tory represents a class. You are expected to write a code:
#
# *   Get the list of class directories from the train folder.
# *   Select one image randomly from each class.
# *   Display the images in a grid format with two rows using matplotlib.

# %%
import os
import random
import matplotlib.pyplot as plt

def visualize_data(train_data_dir):
    # Get the list of class directories
    class_dirs = [d for d in os.listdir(train_data_dir) ]
    print(class_dirs)

    # Select one image randomly from each class
    images = []
    labels = []
    for class_dir in class_dirs:
        class_path = os.path.join(train_data_dir, class_dir)
        image_files = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
        random_image_file = random.choice(image_files)
        image_path = os.path.join(class_path, random_image_file)
        images.append(plt.imread(image_path))
        labels.append(class_dir)

    # Display the images in a grid format with two rows using matplotlib
    fig, axes = plt.subplots(2, len(class_dirs) // 2, figsize=(12, 6))
    for i, (image, label) in enumerate(zip(images, labels)):
        row = i // (len(class_dirs) // 2)
        col = i % (len(class_dirs) // 2)
        axes[row, col].imshow(image)
        axes[row, col].set_title(label)
        axes[row, col].axis('off')

    plt.tight_layout()
    plt.show()

# %%
visualize_data(train_dir)
# Out:
# ['tucuma', 'graviola', 'guarana', 'acai', 'cupuacu', 'pupunha']

# %% [markdown]
# 2. Check for Corrupted Image: Write a script that verifies whether the image in the train
# directory are valid. If any corrupted images are found, the script must remove the image from
# the directory and print the message which image have been removed, if none found print ”No Corrupted Images Found.”
#
# Hint:
# - Iterate through each class subdirectory and check if each image is valid.
# - Use the Image.open() function to attempt to load each image.
# - If the image is corrupted i.e. raises an IOError or SyntaxError, remove the image from the directory and print f"Removed corrupted image: {image_path}".
# - Maintain a list of all corrupted image paths for reporting.
#
# Expected Output: No corrupted images found.

# %%
import os
from PIL import Image

def check_and_remove_corrupted_images(train_folder):
    corrupted_images = []
    for class_dir in os.listdir(train_folder):
        class_path = os.path.join(train_folder, class_dir)
        if os.path.isdir(class_path):
            for image_file in os.listdir(class_path):
                image_path = os.path.join(class_path, image_file)
                try:
                    with Image.open(image_path) as img:
                        # Verify image format
                        img.verify()
                except (IOError, SyntaxError) as e:
                    corrupted_images.append(image_path)
                    os.remove(image_path)
                    print(f"Removed corrupted image: {image_path}")

    if not corrupted_images:
        print("No corrupted images found.")
    else:
        print(f"Total corrupted images removed: {len(corrupted_images)}")


check_and_remove_corrupted_images(train_dir)
# Out:
# No corrupted images found.

# %%
import tensorflow as tf
# Define image size and batch size
img_height = 128
img_width = 128
batch_size = 32
validation_split = 0.2  # 80% training, 20% validation

# Create a preprocessing layer for normalization
rescale = tf.keras.layers.Rescaling(1./255)  # Normalize pixel values to [0, 1]

# Create training dataset with normalization
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)

# Apply the normalization (Rescaling) to the dataset
train_ds = train_ds.map(lambda x, y: (rescale(x), y))

# Create validation dataset with normalization
val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)

# Apply the normalization (Rescaling) to the validation dataset
val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %%
model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
      tf.keras.layers.MaxPooling2D((2, 2)),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
      tf.keras.layers.MaxPooling2D((2, 2)),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(6, activation='softmax') # 6 for 6 classes of fruits
])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define callbacks
callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
]

# Train the model
history = model.fit(
    train_ds,
    epochs=250,
    batch_size=16,
    validation_data=val_ds,  # Use val_ds for validation
    callbacks=callbacks  # Use callbacks
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.1453 - loss: 2.2346
# Epoch 1: val_loss improved from inf to 1.52278, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 720ms/step - accuracy: 0.1437 - loss: 2.3069 - val_accuracy: 0.0000e+00 - val_loss: 1.5228
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.1991 - loss: 2.4736
# Epoch 2: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 556ms/step - accuracy: 0.2049 - loss: 2.4480 - val_accuracy: 0.5000 - val_loss: 1.5249
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.2407 - loss: 1.7923
# Epoch 3: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 552ms/step - accuracy: 0.2361 - loss: 1.7920 - val_accuracy: 0.0556 - val_loss: 1.7646
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 0.3958 - loss: 1.7347
# Epoch 4: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 774ms/step - accuracy: 0.3906 - loss: 1.7355 - val_accuracy: 0.0000e+00 - val_loss: 1.8104
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.2541 - loss: 1.7290
# Epoch 5: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 564ms/step - accuracy: 0.2600 - loss: 1.7290 - val_accuracy: 0.0556 - val_loss: 1.7624
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.3825 - loss: 1.6967
# Epoch 6: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 433ms/step - accuracy: 0.3980 - loss: 1.6914 - val_accuracy: 0.2778 - val_loss: 1.7085
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.3999 - loss: 1.5715
# Epoch 7: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 453ms/step - accuracy: 0.4006 - loss: 1.5692 - val_accuracy: 0.0000e+00 - val_loss: 1.8473
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.3738 - loss: 1.4657
# Epoch 8: val_loss did not improve from 1.52278
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 491ms/step - accuracy: 0.3811 - loss: 1.4582 - val_accuracy: 0.0556 - val_loss: 1.7518
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.5567 - loss: 1.1927
# Epoch 9: val_loss improved from 1.52278 to 1.26687, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 912ms/step - accuracy: 0.5460 - loss: 1.2055 - val_accuracy: 0.5000 - val_loss: 1.2669
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6944 - loss: 1.0606
# Epoch 10: val_loss improved from 1.26687 to 1.26080, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 515ms/step - accuracy: 0.6979 - loss: 1.0652 - val_accuracy: 0.3889 - val_loss: 1.2608
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.7801 - loss: 0.9082
# Epoch 11: val_loss did not improve from 1.26080
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 427ms/step - accuracy: 0.7795 - loss: 0.8997 - val_accuracy: 0.2222 - val_loss: 1.6732
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8513 - loss: 0.6966
# Epoch 12: val_loss improved from 1.26080 to 0.74980, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 543ms/step - accuracy: 0.8433 - loss: 0.6971 - val_accuracy: 0.8333 - val_loss: 0.7498
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8704 - loss: 0.5278
# Epoch 13: val_loss did not improve from 0.74980
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 568ms/step - accuracy: 0.8681 - loss: 0.5265 - val_accuracy: 0.7778 - val_loss: 0.7681
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.8600 - loss: 0.3918
# Epoch 14: val_loss did not improve from 0.74980
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 784ms/step - accuracy: 0.8602 - loss: 0.3886 - val_accuracy: 0.3333 - val_loss: 1.1692
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8403 - loss: 0.3559
# Epoch 15: val_loss improved from 0.74980 to 0.40180, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 494ms/step - accuracy: 0.8385 - loss: 0.3553 - val_accuracy: 0.9444 - val_loss: 0.4018
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9109 - loss: 0.3264
# Epoch 16: val_loss improved from 0.40180 to 0.30593, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 608ms/step - accuracy: 0.9054 - loss: 0.3361 - val_accuracy: 0.9444 - val_loss: 0.3059
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9601 - loss: 0.1869
# Epoch 17: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 566ms/step - accuracy: 0.9596 - loss: 0.1874 - val_accuracy: 0.7222 - val_loss: 0.9079
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9705 - loss: 0.1563
# Epoch 18: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 489ms/step - accuracy: 0.9674 - loss: 0.1620 - val_accuracy: 0.6667 - val_loss: 1.0243
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9601 - loss: 0.1241
# Epoch 19: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - accuracy: 0.9596 - loss: 0.1253 - val_accuracy: 0.8333 - val_loss: 0.5126
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 1.0000 - loss: 0.0743
# Epoch 20: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 823ms/step - accuracy: 1.0000 - loss: 0.0757 - val_accuracy: 0.8889 - val_loss: 0.3085
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 1.0000 - loss: 0.0773
# Epoch 21: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 771ms/step - accuracy: 1.0000 - loss: 0.0765 - val_accuracy: 0.8889 - val_loss: 0.3184
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 22: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 514ms/step - accuracy: 1.0000 - loss: 0.0399 - val_accuracy: 0.8333 - val_loss: 0.5426
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 1.0000 - loss: 0.0478
# Epoch 23: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 504ms/step - accuracy: 1.0000 - loss: 0.0453 - val_accuracy: 0.8333 - val_loss: 0.6289
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 24: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 499ms/step - accuracy: 1.0000 - loss: 0.0279 - val_accuracy: 0.8333 - val_loss: 0.5585
# Epoch 25/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 25: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 492ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.8889 - val_loss: 0.3929
# Epoch 26/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 26: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.8889 - val_loss: 0.3414
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %%
# Create test dataset with normalization
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False  # Important to keep test data in original order
)

# Apply the normalization (Rescaling) to the test dataset
test_ds = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 30 files belonging to 6 classes.

# %%
# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(test_ds)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.7000 - loss: 0.7258
# Test Loss: 0.7257715463638306
# Test Accuracy: 0.699999988079071

# %%
# Plot training and validation accuracy
plt.figure(figsize=(7, 7))
# Accuracy plot

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Loss plot
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Task - 1:**

# %% [markdown]
# Repeat all the task from worksheet - 5 but, try to improve the model from last week with same dataset.
#
# Use Data Augmentation to increase the number of training image.
# Use deeper model with BN and DropOut layer as presented above.
# Understand the Model Summary and Training Behavior.

# %%
data_augmentation_layers = [
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.1),
]

def data_augmentation(images):
  for layer in data_augmentation_layers:
    images = layer(images)
  return images

# %%
# Define an improved CNN model with Batch Normalization and Dropout
modelcnn2 = keras.Sequential([

    # Data augmentation applied using Lambda layer
    layers.Lambda(data_augmentation, input_shape=(128,128, 3)),

    # Rescaling layer to normalize pixel values
    layers.Rescaling(1./255),

    layers.Conv2D(32, (3, 3), activation="relu", padding="same"),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),

    layers.Conv2D(64, (3, 3), activation="relu", padding="same"),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(6, activation="softmax")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
modelcnn2.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Display model summary
modelcnn2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                      │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │       8,388,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 6)                   │           1,542 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,485,574 (32.37 MB)
#  Trainable params: 8,484,614 (32.37 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Train the model
cnn_history = modelcnn2.fit(
    train_ds,  # Training dataset
    validation_data=val_ds,  # Validation dataset
    epochs=250,  # Number of epochs
    batch_size=32,  # Batch size
    callbacks=callbacks  # Callbacks for early stopping and saving the best model
    # jit_compile =False # Remove this line - it's not a valid argument for model.fit
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1505 - loss: 2.9533
# Epoch 1: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.1476 - loss: 3.0264 - val_accuracy: 0.1667 - val_loss: 1.7355
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5000 - loss: 1.7659
# Epoch 2: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5000 - loss: 1.7552 - val_accuracy: 0.0000e+00 - val_loss: 1.8553
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5596 - loss: 1.2153
# Epoch 3: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5621 - loss: 1.2076 - val_accuracy: 0.0000e+00 - val_loss: 1.9152
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5804 - loss: 1.0458
# Epoch 4: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5777 - loss: 1.0562 - val_accuracy: 0.0000e+00 - val_loss: 1.9193
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6696 - loss: 0.9380
# Epoch 5: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6723 - loss: 0.9371 - val_accuracy: 0.0000e+00 - val_loss: 1.9256
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6800 - loss: 0.8717
# Epoch 6: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6801 - loss: 0.8844 - val_accuracy: 0.0000e+00 - val_loss: 1.8218
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7315 - loss: 0.6348
# Epoch 7: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7222 - loss: 0.6521 - val_accuracy: 0.0000e+00 - val_loss: 1.7270
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7008 - loss: 0.8356
# Epoch 8: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6957 - loss: 0.8362 - val_accuracy: 0.0000e+00 - val_loss: 1.6277
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8160 - loss: 0.5649
# Epoch 9: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8099 - loss: 0.5827 - val_accuracy: 0.0000e+00 - val_loss: 1.5154
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7402 - loss: 0.6153
# Epoch 10: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.7391 - loss: 0.6339 - val_accuracy: 0.8333 - val_loss: 1.4247
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8721 - loss: 0.4753
# Epoch 11: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8589 - loss: 0.5018 - val_accuracy: 0.8333 - val_loss: 1.3551
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7442 - loss: 0.8270
# Epoch 12: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7491 - loss: 0.8095 - val_accuracy: 0.8333 - val_loss: 1.2763
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7708 - loss: 0.5495
# Epoch 13: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7656 - loss: 0.5635 - val_accuracy: 0.8333 - val_loss: 1.2348
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7182 - loss: 0.6211
# Epoch 14: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7296 - loss: 0.5963 - val_accuracy: 0.8333 - val_loss: 1.1667
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7089 - loss: 0.5782
# Epoch 15: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.7157 - loss: 0.5798 - val_accuracy: 0.8333 - val_loss: 1.0861
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7703 - loss: 0.5864
# Epoch 16: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7687 - loss: 0.5845 - val_accuracy: 0.8333 - val_loss: 1.0310
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7448 - loss: 0.5972
# Epoch 17: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7461 - loss: 0.6008 - val_accuracy: 0.8333 - val_loss: 1.0202
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7656 - loss: 0.6925
# Epoch 18: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7617 - loss: 0.7019 - val_accuracy: 0.8333 - val_loss: 1.0527
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8605 - loss: 0.4084
# Epoch 19: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8572 - loss: 0.4092 - val_accuracy: 0.8333 - val_loss: 1.1204
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8814 - loss: 0.3710
# Epoch 20: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8728 - loss: 0.3944 - val_accuracy: 0.8333 - val_loss: 1.2059
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8241 - loss: 0.4587
# Epoch 21: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8299 - loss: 0.4518 - val_accuracy: 0.8333 - val_loss: 1.2959
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8212 - loss: 0.4702
# Epoch 22: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.8138 - loss: 0.4941 - val_accuracy: 0.8333 - val_loss: 1.3830
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8802 - loss: 0.3252
# Epoch 23: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.8789 - loss: 0.3359 - val_accuracy: 0.8333 - val_loss: 1.4845
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8814 - loss: 0.3448
# Epoch 24: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8728 - loss: 0.3638 - val_accuracy: 0.8333 - val_loss: 1.5859
# Epoch 25/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8403 - loss: 0.4620
# Epoch 25: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.8385 - loss: 0.4704 - val_accuracy: 0.8333 - val_loss: 1.6848
# Epoch 26/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8391 - loss: 0.4786
# Epoch 26: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8446 - loss: 0.4621 - val_accuracy: 0.8333 - val_loss: 1.7747
# Epoch 27/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8906 - loss: 0.3391
# Epoch 27: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.8867 - loss: 0.3473 - val_accuracy: 0.8333 - val_loss: 1.8588
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,              # No shuffling for consistent evaluation
)

# Apply the same normalization as train/val
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

# Evaluate the model on the test dataset
test_loss, test_accuracy = modelcnn2.evaluate(test_ds)
print(f"\n\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.1667 - loss: 4.5890
#
#
# Test Loss: 4.5890, Test Accuracy: 0.1667

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 12))

# Accuracy plot
plt.subplot(2, 1, 1)
plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Loss plot
plt.subplot(2, 1, 2)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **MobilenetV2**

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input

# Define input shape
input_shape = (128, 128, 3)
base_model = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Add custom layers on top
inputs = Input(shape=input_shape)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(6, activation='softmax')(x)  # Adjust to your number of classes

# Create the model
modelnetv2 = Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import Adam

modelnetv2.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
vnet2_history = modelnetv2.fit(
    train_ds,
    validation_data=val_ds,
    epochs=250,
    batch_size=16,
    callbacks=callbacks
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.1696 - loss: 2.4754
# Epoch 1: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.1723 - loss: 2.4579 - val_accuracy: 0.7222 - val_loss: 1.0567
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.6753 - loss: 0.9361
# Epoch 2: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 443ms/step - accuracy: 0.6732 - loss: 0.9401 - val_accuracy: 0.8333 - val_loss: 0.8086
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.8900 - loss: 0.5478
# Epoch 3: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.8898 - loss: 0.5370 - val_accuracy: 0.8889 - val_loss: 0.5762
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9560 - loss: 0.2336
# Epoch 4: val_loss did not improve from 0.30593
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 447ms/step - accuracy: 0.9497 - loss: 0.2382 - val_accuracy: 0.9444 - val_loss: 0.4026
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9699 - loss: 0.1418
# Epoch 5: val_loss improved from 0.30593 to 0.29391, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 585ms/step - accuracy: 0.9705 - loss: 0.1413 - val_accuracy: 0.9444 - val_loss: 0.2939
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9653 - loss: 0.1277
# Epoch 6: val_loss improved from 0.29391 to 0.26074, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 551ms/step - accuracy: 0.9635 - loss: 0.1294 - val_accuracy: 0.9444 - val_loss: 0.2607
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 1.0000 - loss: 0.0727
# Epoch 7: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 670ms/step - accuracy: 1.0000 - loss: 0.0719 - val_accuracy: 0.9444 - val_loss: 0.2705
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0315
# Epoch 8: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 393ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 0.9444 - val_loss: 0.3028
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.0218
# Epoch 9: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.9444 - val_loss: 0.3353
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 10: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 416ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 0.9444 - val_loss: 0.3531
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 1.0000 - loss: 0.0226
# Epoch 11: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 422ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9444 - val_loss: 0.3609
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 12: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 483ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.9444 - val_loss: 0.3594
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 13: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 735ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9444 - val_loss: 0.3482
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 14: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 501ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9444 - val_loss: 0.3378
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 15: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9444 - val_loss: 0.3357
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 16: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.9444 - val_loss: 0.3373
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
modelnetv2.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_128 (Functional)    │ (None, 4, 4, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,752,212 (10.50 MB)
#  Trainable params: 164,742 (643.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 329,486 (1.26 MB)

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,              # No shuffling for consistent evaluation
)

# Apply the same normalization as train/val
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

# Evaluate the model on the test dataset
test_loss, test_accuracy = modelnetv2.evaluate(test_ds)
print(f"\n\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step - accuracy: 0.7333 - loss: 0.6710
#
#
# Test Loss: 0.6710, Test Accuracy: 0.7333

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 12))

# Accuracy plot
plt.subplot(2, 1, 1)
plt.plot(vnet2_history.history['accuracy'], label='Training Accuracy')
plt.plot(vnet2_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Loss plot
plt.subplot(2, 1, 2)
plt.plot(vnet2_history.history['loss'], label='Training Loss')
plt.plot(vnet2_history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **VGG16**

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input

# %%
# Load the VGG16 model pre-trained on ImageNet, without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128,128, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
# Add custom layers on top of the pre-trained model
x = base_model.output
x = GlobalAveragePooling2D()(x) # Reduces dimensions (height, width) to a single vector per image
x = Dense(1024, activation='relu')(x) # Fully connected layer with 1024 neurons
x = Dense(10, activation='softmax')(x) # Output layer for 10 classes (with softmax for multi-class classification)

# %%
from tensorflow.keras.models import Model
# Create the final model
modelvgg16 = Model(inputs=base_model.input, outputs=x)

# %%
from tensorflow.keras.optimizers import Adam
# Compile the model
modelvgg16.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
vgg_history = modelvgg16.fit(
    train_ds,
    validation_data=val_ds,
    epochs=250,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1082 - loss: 2.2855
# Epoch 1: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 0.1194 - loss: 2.2593 - val_accuracy: 0.5556 - val_loss: 1.5136
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5289 - loss: 1.5113
# Epoch 2: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.5356 - loss: 1.5020 - val_accuracy: 0.5556 - val_loss: 1.1590
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6858 - loss: 1.2227
# Epoch 3: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.6810 - loss: 1.2274 - val_accuracy: 0.6667 - val_loss: 1.1083
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8148 - loss: 0.9895
# Epoch 4: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 0.8160 - loss: 0.9865 - val_accuracy: 0.5556 - val_loss: 1.1045
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6655 - loss: 0.9734
# Epoch 5: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.6623 - loss: 0.9689 - val_accuracy: 0.5556 - val_loss: 1.1425
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7384 - loss: 0.8546
# Epoch 6: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.7483 - loss: 0.8383 - val_accuracy: 0.5556 - val_loss: 0.9187
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8293 - loss: 0.6990
# Epoch 7: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 0.8338 - loss: 0.6908 - val_accuracy: 0.7222 - val_loss: 0.7629
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9456 - loss: 0.5777
# Epoch 8: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.9418 - loss: 0.5783 - val_accuracy: 0.7222 - val_loss: 0.7681
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9259 - loss: 0.4673
# Epoch 9: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step - accuracy: 0.9201 - loss: 0.4766 - val_accuracy: 0.7222 - val_loss: 0.8394
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9606 - loss: 0.4103
# Epoch 10: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 0.9566 - loss: 0.4179 - val_accuracy: 0.7222 - val_loss: 0.8361
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9294 - loss: 0.4075
# Epoch 11: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 0.9332 - loss: 0.4042 - val_accuracy: 0.8889 - val_loss: 0.6769
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9797 - loss: 0.3466
# Epoch 12: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.9813 - loss: 0.3397 - val_accuracy: 0.8333 - val_loss: 0.5000
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9751 - loss: 0.2867
# Epoch 13: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step - accuracy: 0.9744 - loss: 0.2878 - val_accuracy: 0.8889 - val_loss: 0.4751
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9902 - loss: 0.2814
# Epoch 14: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 0.9891 - loss: 0.2777 - val_accuracy: 0.8889 - val_loss: 0.5595
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9902 - loss: 0.2021
# Epoch 15: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.9891 - loss: 0.2075 - val_accuracy: 0.8333 - val_loss: 0.5998
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9902 - loss: 0.1903
# Epoch 16: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 7s/step - accuracy: 0.9891 - loss: 0.1933 - val_accuracy: 0.8333 - val_loss: 0.5991
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9902 - loss: 0.1913
# Epoch 17: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 0.9891 - loss: 0.1911 - val_accuracy: 0.9444 - val_loss: 0.5086
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.1634
# Epoch 18: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.1638 - val_accuracy: 0.9444 - val_loss: 0.4236
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.1395
# Epoch 19: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.1394 - val_accuracy: 0.9444 - val_loss: 0.4099
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.1175
# Epoch 20: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 1.0000 - loss: 0.1202 - val_accuracy: 0.9444 - val_loss: 0.3886
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.1206
# Epoch 21: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.1202 - val_accuracy: 0.9444 - val_loss: 0.3447
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.1025
# Epoch 22: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.1035 - val_accuracy: 0.9444 - val_loss: 0.3503
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0899
# Epoch 23: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 26s 9s/step - accuracy: 1.0000 - loss: 0.0912 - val_accuracy: 0.8889 - val_loss: 0.3837
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0839
# Epoch 24: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 1.0000 - loss: 0.0837 - val_accuracy: 0.8889 - val_loss: 0.4245
# Epoch 25/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0772
# Epoch 25: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.0776 - val_accuracy: 0.8889 - val_loss: 0.4338
# Epoch 26/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0736
# Epoch 26: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 1.0000 - loss: 0.0748 - val_accuracy: 0.8889 - val_loss: 0.3961
# Epoch 27/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0681
# Epoch 27: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step - accuracy: 1.0000 - loss: 0.0680 - val_accuracy: 0.9444 - val_loss: 0.3228
# Epoch 28/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0591
# Epoch 28: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 1.0000 - loss: 0.0596 - val_accuracy: 0.9444 - val_loss: 0.3076
# Epoch 29/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0572
# Epoch 29: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.0577 - val_accuracy: 0.8889 - val_loss: 0.3213
# Epoch 30/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0576
# Epoch 30: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 1.0000 - loss: 0.0570 - val_accuracy: 0.8889 - val_loss: 0.3649
# Epoch 31/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0519
# Epoch 31: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 1.0000 - loss: 0.0516 - val_accuracy: 0.8889 - val_loss: 0.4120
# Epoch 32/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0529
# Epoch 32: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 1.0000 - loss: 0.0519 - val_accuracy: 0.8889 - val_loss: 0.4105
# Epoch 33/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0448
# Epoch 33: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step - accuracy: 1.0000 - loss: 0.0449 - val_accuracy: 0.8889 - val_loss: 0.3827
# Epoch 34/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0484
# Epoch 34: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step - accuracy: 1.0000 - loss: 0.0467 - val_accuracy: 0.8889 - val_loss: 0.3435
# Epoch 35/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 35: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 0.9444 - val_loss: 0.3252
# Epoch 36/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0386
# Epoch 36: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.0379 - val_accuracy: 0.8889 - val_loss: 0.3272
# Epoch 37/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0321
# Epoch 37: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.0325 - val_accuracy: 0.8889 - val_loss: 0.3322
# Epoch 38/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 38: val_loss did not improve from 0.26074
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 0.8889 - val_loss: 0.3390
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,              # No shuffling for consistent evaluation
)

# Apply the same normalization as train/val
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

# Evaluate the model on the test dataset
test_loss, test_accuracy = modelvgg16.evaluate(test_ds)
print(f"\n\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.5333 - loss: 1.3625
#
#
# Test Loss: 1.3625, Test Accuracy: 0.5333

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 12))

# Accuracy plot
plt.subplot(2, 1, 1)
plt.plot(vnet2_history.history['accuracy'], label='Training Accuracy')
plt.plot(vnet2_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Loss plot
plt.subplot(2, 1, 2)
plt.plot(vnet2_history.history['loss'], label='Training Loss')
plt.plot(vnet2_history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
